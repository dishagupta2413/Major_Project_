# %%
import pandas as pd
import os

# %%
# os.chdir('D:\\Major_Project')

# %%
os.chdir('D:\MajorProject\Datasets_1')

# %%
os.getcwd()
# Out:
# 'D:\\MajorProject\\Datasets_1'

# %%
import csv

# %%
df = pd.read_csv("D:\\MajorProject\\Datasets_1\\Reliance Industries Ltd.csv", sep = ",", low_memory = False)

# %%
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     2008-01-01   715.715759   717.944580   702.119629   705.376221
# 1     2008-01-02   707.047913   714.229797   696.225464   708.719543
# 2     2008-01-03   706.304932   725.621826   700.918518   719.108582
# 3     2008-01-04   719.182861   747.861023   719.182861   741.223938
# 4     2008-01-07   736.716675   750.387085   733.051392   747.972473
# ...          ...          ...          ...          ...          ...
# 2952  2019-12-23  1545.450684  1562.736816  1543.172241  1556.644531
# 2953  2019-12-24  1554.168091  1557.288452  1528.015991  1531.928833
# 2954  2019-12-26  1527.173950  1538.367798  1495.969727  1501.170410
# 2955  2019-12-27  1512.661499  1531.681152  1507.015015  1527.867310
# 2956  2019-12-30  1531.433594  1533.117554  1513.701660  1529.699951
#
#         Adj Close      Volume
# 0      630.190979   4864461.0
# 1      633.178162  12588005.0
# 2      642.459778  13939233.0
# ...

# %%
# df = pd.DataFrame(df, columns=['Date', 'Open', 'High','Low', 'Close', 'Adjusted Close', 'Volume'])

# %%
# delimiter = ','

# %%
# df = pd.read_csv("D:\\MajorProject\\Datasets_1\\Reliance Industries Ltd.csv", sep=delimiter)

# %%
# df

# %%
df['Company']= 'Reliance Industries Ltd'

# %%
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     2008-01-01   715.715759   717.944580   702.119629   705.376221
# 1     2008-01-02   707.047913   714.229797   696.225464   708.719543
# 2     2008-01-03   706.304932   725.621826   700.918518   719.108582
# 3     2008-01-04   719.182861   747.861023   719.182861   741.223938
# 4     2008-01-07   736.716675   750.387085   733.051392   747.972473
# ...          ...          ...          ...          ...          ...
# 2952  2019-12-23  1545.450684  1562.736816  1543.172241  1556.644531
# 2953  2019-12-24  1554.168091  1557.288452  1528.015991  1531.928833
# 2954  2019-12-26  1527.173950  1538.367798  1495.969727  1501.170410
# 2955  2019-12-27  1512.661499  1531.681152  1507.015015  1527.867310
# 2956  2019-12-30  1531.433594  1533.117554  1513.701660  1529.699951
#
#         Adj Close      Volume                  Company
# 0      630.190979   4864461.0  Reliance Industries Ltd
# ...

# %%
# os.chdir('D:\MajorProject\Datasets_1')

# %%
# os.getcwd()

# %%
df.to_csv('New_Reliance Industries Ltd.csv', index=False)

# %%
l=["HDFC Bank Ltd", "Infosys Ltd", "Maruti Suzuki India Ltd", "Tata Consultancy Services", "Tata Steel Ltd", "Bajaj Finserv Ltd", "Cipla Ltd", "Hero Motocorp Ltd", "Kotak Mahindra Bank Ltd", "Nestle India Ltd", "Wipro Ltd","Britannia Industries Ltd","HCL Technologies Ltd", "JSW Steel Ltd","State Bank of India","Eicher Motors Ltd","Hindalco Industries Ltd", "Asian Paints Ltd","Hindustan Unilever Ltd","ITC Ltd","Mahindra&Mahindra"]

# %%
len(l)
# Out:
# 21

# %%
j=0
combined_df = df
for i in l:
    s = l[j]
    df = pd.read_csv("D:\\MajorProject\\Datasets_1\\"+s+".csv", sep = ",", low_memory = False)
    df['Company']= s
    df.to_csv('New_'+s+'.csv', index=False)
    combined_df = pd.concat([combined_df, df], ignore_index=True)
    j=j+1

# %%
# d1=pd.read_csv("Datasets_1\\New_Bajaj Finserv Ltd.csv")
# d2=pd.read_csv("Datasets_1\\New_HDFC Bank Ltd.csv")

# %%
combined_df
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 0      2008-01-01  715.715759  717.944580  702.119629  705.376221  630.190979
# 1      2008-01-02  707.047913  714.229797  696.225464  708.719543  633.178162
# 2      2008-01-03  706.304932  725.621826  700.918518  719.108582  642.459778
# 3      2008-01-04  719.182861  747.861023  719.182861  741.223938  662.217773
# 4      2008-01-07  736.716675  750.387085  733.051392  747.972473  668.247131
# ...           ...         ...         ...         ...         ...         ...
# 65049  2019-12-23  529.950012  535.900024  524.700012  525.900024  502.017120
# 65050  2019-12-24  529.000000  532.650024  526.200012  527.500000  503.544373
# 65051  2019-12-26  530.000000  536.200012  527.049988  528.349976  504.355682
# 65052  2019-12-27  529.900024  532.750000  525.049988  530.150024  506.074066
# 65053  2019-12-30  531.349976  539.849976  531.349976  536.900024  512.517456
#
# ...

# %%
combined_df.to_csv('ZFinal_dataset.csv', index=False)

# %%
combined_df["Company"].nunique()
# Out:
# 22
