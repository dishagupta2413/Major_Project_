# %%
import pandas as pd
import numpy as np

# df=pd.read_csv("../Datasets_1/Final Dataset1/Dataset2New1_Reliance Industries Ltd.csv")
# df
# df_clean=df.dropna()
# df_clean

# start_date = '2008-01-01'
# end_date_training = '2018-12-31'
# end_date_test = '2019-12-31'

# training_data = df_clean[(df_clean['Date'] >= start_date) & (df_clean['Date'] <= end_date_training)]
# test_data = df_clean[(df['Date'] > end_date_training) & (df_clean['Date'] <= end_date_test)]

# training_data.to_csv("../Datasets_1/Training Dataset/Reliance_Industries.csv", index=False)
# test_data.to_csv("../Datasets_1/Testing Dataset/Reliance_Industries.csv", index=False)

l=["Dataset2New1_Asian Paints Ltd.csv","Dataset2New1_Bajaj Finserv Ltd.csv","Dataset2New1_Britannia Industries Ltd.csv","Dataset2New1_Cipla Ltd.csv","Dataset2New1_Eicher Motors Ltd.csv","Dataset2New1_HCL Technologies Ltd.csv","Dataset2New1_HDFC Bank Ltd.csv","Dataset2New1_Hero Motocorp Ltd.csv","Dataset2New1_Hindalco Industries Ltd.csv","Dataset2New1_Hindustan Unilever Ltd.csv","Dataset2New1_Infosys Ltd.csv","Dataset2New1_ITC Ltd.csv","Dataset2New1_JSW Steel Ltd.csv","Dataset2New1_Kotak Mahindra Bank Ltd.csv","Dataset2New1_Mahindra&Mahindra.csv","Dataset2New1_Maruti Suzuki India Ltd.csv","Dataset2New1_Nestle India Ltd.csv",
   "Dataset2New1_Reliance Industries Ltd.csv",
   "Dataset2New1_State Bank of India.csv","Dataset2New1_Tata Consultancy Services.csv","Dataset2New1_Tata Steel Ltd.csv","Dataset2New1_Wipro Ltd.csv"]

name=["Asian_Paints_Ltd", 
      "Bajaj_Finserv_Ltd",
      "Britannia_Industries_Ltd",
      "Cipla_Ltd",
      "Eicher_Motors_Ltd",
      "HCL_Technologies_Ltd",
      "HDFC_Bank_Ltd", 
      "Hero Motocorp Ltd",
      "Hindalco_Industries_Ltd",
      "Hindustan_Unilever_Ltd",
      "Infosys_Ltd", 
      "ITC_Ltd",
      "JSW_Steel_Ltd",
      "Kotak_Mahindra_Bank_Ltd", 
      "Mahindra&Mahindra",
      "Maruti_Suzuki_India_Ltd",
      "Nestle_India_Ltd",
      "Reliance_Industries_Ltd",
        "State_Bank_of_India",
        "Tata Consultancy Services", 
        "Tata Steel Ltd",
         "Wipro Ltd"]


start_date = '2008-01-01'
end_date_training = '2018-12-31'
end_date_test = '2019-12-31'

j=0;
for i in l:
    s=l[j]
    t=name[j]
    df=pd.read_csv("../Datasets_1/Final Dataset1/"+s)
    df_clean=df.dropna()
    training_data = df_clean[(df_clean['Date'] >= start_date) & (df_clean['Date'] <= end_date_training)]
    test_data = df_clean[(df['Date'] > end_date_training) & (df_clean['Date'] <= end_date_test)]

    training_data.to_csv("../Datasets_1/Training Dataset/"+t+".csv", index=False)
    test_data.to_csv("../Datasets_1/Testing Dataset/"+t+".csv", index=False)
    j=j+1
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_18836\83285104.py:58: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   test_data = df_clean[(df['Date'] > end_date_training) & (df_clean['Date'] <= end_date_test)]
# C:\Users\Hp\AppData\Local\Temp\ipykernel_18836\83285104.py:58: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   test_data = df_clean[(df['Date'] > end_date_training) & (df_clean['Date'] <= end_date_test)]
# C:\Users\Hp\AppData\Local\Temp\ipykernel_18836\83285104.py:58: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   test_data = df_clean[(df['Date'] > end_date_training) & (df_clean['Date'] <= end_date_test)]
# C:\Users\Hp\AppData\Local\Temp\ipykernel_18836\83285104.py:58: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   test_data = df_clean[(df['Date'] > end_date_training) & (df_clean['Date'] <= end_date_test)]
# ...

# %%
df=pd.read_csv("../Datasets_1/Training Dataset/Asian_Paints_Ltd.csv")
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     2008-01-01   113.900002   114.599998   109.105003   113.410004
# 1     2008-01-02   113.500000   116.500000   111.205002   113.629997
# 2     2008-01-03   114.099998   114.889999   112.300003   113.904999
# 3     2008-01-04   115.000000   115.790001   111.099998   114.089996
# 4     2008-01-07   114.089996   122.099998   107.769997   121.239998
# ...          ...          ...          ...          ...          ...
# 2703  2018-12-24  1388.000000  1388.949951  1351.099976  1357.050049
# 2704  2018-12-26  1367.949951  1374.900024  1347.400024  1363.000000
# 2705  2018-12-27  1360.050049  1384.750000  1354.300049  1372.500000
# 2706  2018-12-28  1383.000000  1383.000000  1359.000000  1366.000000
# 2707  2018-12-31  1375.000000  1378.000000  1367.300049  1373.050049
#
#         Adj Close     Volume           Company  Year  GDP Growth Rate  \
# ...
