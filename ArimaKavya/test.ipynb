# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("../Datasets_1/Training Dataset/Reliance_Industries_Ltd.csv")

plt.plot(df['Close'])

# %%
df_diff=df['Close'].diff();
plt.plot(df_diff)

# %%
#to check stationarity
from statsmodels.tsa.stattools import adfuller

df_diff=df['Close'].diff().dropna()

#function checks stationarity
def check_stationarity(timeseries):

    result=adfuller(timeseries)
    print('ADF Statistic:', result[0])
    print('p-value:', result[1])
    print('Critical Values:', result[4])

    if result[1] <= 0.05:
        print('Stationary (Reject the null hypothesis)')
    else:
        print('Non-Stationary (Fail to reject the null hypothesis)')

check_stationarity(df_diff)
# Out:
# ADF Statistic: -12.510027345971794
# p-value: 2.68707035333134e-23
# Critical Values: {'1%': -3.4327832903814204, '5%': -2.8626150481453765, '10%': -2.567342284103315}
# Stationary (Reject the null hypothesis)

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

plt.figure(figsize=(12, 6))
plot_acf(df_diff, lags=40, title='Autocorrelation Function (ACF)')
plt.show()

plt.figure(figsize=(12, 6))
plot_pacf(df_diff, lags=40, title='Partial Autocorrelation Function (PACF)')
plt.show()
